# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

dist_summary = []

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load, encoding="ISO-8859-1")
student_data = pd.read_csv(student_data_to_load, encoding="ISO-8859-1")

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="inner", on=["school_name", "school_name"])
school_data_group = school_data_complete.groupby(by= 'School ID', as_index = False).first()

# storing the merged dataset into a different for use during the analysis
dist_schools = pd.DataFrame(school_data_complete)
#dist_schools.count()
#dist_schools.describe()
#dist_schools.info()

# %%
#---------------------TESTING numpy:ilco and pandas:loc--------------------

#Indexing the numpy way requieres row and column positions
#dist_schools.iloc[:, 6:7].mean() # The numpy way.

#Indexing the pandas way allows the us of labels
#dist_schools.loc[0:5, :]
dist_schools.head()
#dist_schools.index
#dist_schools.loc[:,'budget']
#dist_schools
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#total_schools = dist_schools.iloc[:, 4:5].nunique()
#total_schools = dist_schools.loc[:,'school_name'].nunique()
#total_schools = dist_schools["school_name"].nunique()
#print(total_schools)
#type(total_schools)

# %%
total_schools = dist_schools.loc[:,'school_name'].nunique()

# %%
#total_student = dist_schools.iloc[:, 1:2].nunique()
#total_students = dist_schools.loc[:,'student_name'].nunique()
#total_students = len(dist_schools["student_name"])
#print(total_students)
#type(total_students)

# %%
total_students = dist_schools.loc[:,'student_name'].nunique()

# %%
#budget = dist_schools.iloc[:, 10:11].sum()
#budget =  dist_schools.loc[:,'budget'].sum() ## ?????????FIND OUT WHY THIS DOESN'T GIVE THE CORRECT TOTAL
#budget = school_data["budget"].sum()
#print(budget)
#type(budget)

# %%
#avg_math_score = dist_schools.iloc[:, 6:7].mean() ## numpy way
#avg_math_score = dist_schools.loc[:,'math_score'].mean() ## pandas way
#avg_math_score = dist_schools["math_score"].mean()
#avg_math_score = dist_schools["math_score"].sum()/len(dist_schools["math_score"]) ## silly way
#print(avg_math_score)
#type(avg_math_score)

# %%
avg_math_score = dist_schools.loc[:,'math_score'].mean()

# %%
#avg_reading_score = dist_schools.iloc[:, 5:6].mean()
#dist_schools.loc[:,'reading_score'].nunique()
#avg_reading_score = dist_schools["reading_score"].mean()
#avg_reading_score = school_data_complete["reading_score"].sum()/len(student_data["reading_score"])
#print(avg_reading_score)
#type(avg_reading_score)

# %%
dist_schools.loc[:,'reading_score'].nunique()
# Out:
# 37

# %%
dist_summary = [{'Total Schools': total_schools, 'Total Students': total_students, 'Total Budget': budget,
                 'Average Math Score': avg_math_score, 'Average Reading Score' : avg_reading_score}] 
                 #'% Passing Math': number_prch, '% Passing Reading': , 'Overall Passing Rate': }]
#print(dist_summary)

# %%
dist_summary = pd.DataFrame(data=dist_summary, columns=['Total Schools', 'Total Students', 'Total Budget', 
                                                                'Average Math Score', 'Average Reading Score'])
#'% Passing Math', '% Passing Reading', 'Overall Passing Rate' ])
#print(dist_summary)

# %%
dist_summary['Total Schools'] = dist_summary["Total Schools"].map("{:,}".format)
dist_summary['Total Students'] = dist_summary["Total Students"].map("{:,}".format)
dist_summary['Total Budget'] = dist_summary["Total Budget"].map("${:,.2f}".format)
dist_summary['Average Math Score'] = dist_summary["Average Math Score"].map("{:,.5f}".format)
dist_summary['Average Reading Score'] = dist_summary["Average Reading Score"].map("{:,.5f}".format)

dist_summary
# Out:
#   Total Schools Total Students    Total Budget Average Math Score  \
# 0            15         32,715  $24,649,428.00           78.98537
#
#   Average Reading Score
# 0              81.87784

# %%
passing_math = dist_schools["math_score"] >= 70
# filtered_reviews = reviews[score_filter]
# filtered_reviews.head(
passing_math = dist_schools[passing_math]
#passing_math = school_data_complete.loc["math_score"]
#idx = df.index[df['BoolCol']]
#school_data_complete["math_score"] >= 70
#passing_math = student_data["math_score"] >= 60
#passing_math = passing_math.count(True)
passing_math
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# 12             12      Brittney Walker      F   9th   Huang High School
# 13             13         William Long      M   9th   Huang High School
# 15             15    Dr. Jordan Carson      M  11th   Huang High School
# 17             17    Kimberly Santiago      F   9th   Huang High School
# ...
